# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6fa82794-30d0-4d8f-8dce-5793c89f4fe8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6fa82794-30d0-4d8f-8dce-5793c89f4fe8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

# Replace 'your_file.csv' with the name of your uploaded CSV file
df = pd.read_csv(io.BytesIO(uploaded['final (1).csv']), header=None)

# %%
# Reshape the DataFrame
reshaped_df = df.values.reshape(-1, 3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-613c8e93fd6d> in <cell line: 2>()
#       1 # Reshape the DataFrame
# ----> 2 reshaped_df = df.values.reshape(-1, 3)
#
# ValueError: cannot reshape array of size 2150 into shape (3)

# %%
data = df[0].values

# %%
n_missing = (3 - len(data) % 3) % 3

# %%
if n_missing > 0:
    data = np.append(data, [np.nan] * n_missing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-3c7cf67601a7> in <cell line: 1>()
#       1 if n_missing > 0:
# ----> 2     data = np.append(data, [np.nan] * n_missing)
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
if n_missing > 0:
    data = np.append(data, [np.nan] * n_missing)

# %%
reshaped_data = data.reshape(-1, 3)

# %%
reshaped_df = pd.DataFrame(reshaped_data, columns=['Column1', 'Column2', 'Column3'])

# %%
reshaped_df.to_csv('transformed_file.csv', index=False)

# %%
files.download('transformed_file.csv')

# %%
import pandas as pd
import numpy as np
from google.colab import files
import io

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e828ef16-abf9-48fd-945b-5fa32701214c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e828ef16-abf9-48fd-945b-5fa32701214c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(io.BytesIO(uploaded['final (2).csv']), header=None)

# %%
data = df[0].values

# %%
n_missing = (3 - len(data) % 3) % 3

# %%
if n_missing > 0:
    data = np.append(data, [np.nan] * n_missing)

# %%
reshaped_data = data.reshape(-1, 3)

# %%
reshaped_df = pd.DataFrame(reshaped_data, columns=['Column1', 'Column2', 'Column3'])

# %%
reshaped_df.to_csv('transformed_file.csv', index=False)

# %%
files.download('transformed_file.csv')
